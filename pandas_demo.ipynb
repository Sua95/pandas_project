# %%
import pandas as pd

# %%
df = pd.read_csv('List of best-selling video games.csv')

# %%
df
# Out:
#                                                   RANK           SALES  \
# Title
# Minecraft                                          1.0  238,000,000[b]
# Grand Theft Auto V                                 2.0     170,000,000
# Tetris (EA)                                        3.0     100,000,000
# Wii Sports                                         4.0      82,900,000
# PUBG: Battlegrounds                                5.0      75,000,000
# Super Mario Bros.                                  6.0      58,000,000
# Mario Kart 8 / Deluxe                              7.0      56,870,000
# Pokémon Red / Green / Blue / Yellow                8.0      47,520,000
# Red Dead Redemption 2                              9.0      46,000,000
# Terraria                                          10.0      44,500,000
# Wii Fit / Plus                                    11.0      43,800,000
# Tetris (1989)[j]                                  12.0      43,000,000
# ...

# %%
df.shape
# Out:
# (49, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  49 non-null     float64
#  1   Title                 49 non-null     object
#  2   Sales                 43 non-null     object
#  3   Series                49 non-null     object
#  4   Platform(s)           49 non-null     object
#  5   Initial release date  49 non-null     object
#  6   Developer(s)[a]       49 non-null     object
#  7   Publisher(s)[a]       49 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 3.2+ KB

# %% [markdown]
# Usually objects mean strings

# %% [markdown]
# If we have many columns maybe don't get visualize so we use the pd.set_option("display.max_columns, num_of_columns")

# %% [markdown]
# We can create a data frame with the pandas method .DataFrame like in the example below.

# %% [markdown]
# raw_data = {
#
#     "Name": ["John", "Kevin", "Omar"],
#
#     "Age": [21, 18, 31],
#
#     "In Shape": [True, True, True]
#
# }
#
# new_df = pd.DataFrame(raw_data)
#
# new_df

# %% [markdown]
# We can access certain rows with df["Name of the column"] or df.name_of_the_column
# but with the . if theres a row and a method called the same way will bring you an error
# We also can pass a list of columns to return just that columns or rows [[column_1,column_2]]

# %%
df[["Publisher(s)[a]","Sales"]]
# Out:
#                    Publisher(s)[a]           Sales
# 0                Xbox Game Studios  238,000,000[b]
# 1                   Rockstar Games     170,000,000
# 2                  Electronic Arts     100,000,000
# 3                         Nintendo      82,900,000
# 4                 PUBG Corporation      75,000,000
# 5                         Nintendo      58,000,000
# 6                         Nintendo      56,870,000
# 7                         Nintendo      47,520,000
# 8                   Rockstar Games      46,000,000
# 9             Re-Logic / 505 Games      44,500,000
# 10                        Nintendo      43,800,000
# 11                        Nintendo      43,000,000
# 12                           Namco      42,071,635
# 13                        Nintendo      40,170,000
# 14                      CD Projekt      40,000,000
# 15                        Nintendo      37,380,000
# 16                        Nintendo      33,140,000
# ...

# %% [markdown]
# The .loc and .iloc methods means index location (.iloc), and location (.loc)
#
# with .iloc the first argument is for the row(s) we need, the second argument is for the columns(s).
#
# with .loc the first argument is mostly the same but you can search for the column(s) with the column name.
#
# with the first argument and second we can pass a list or slicing

# %%
df.iloc[0:5, [1,2]]
# Out:
#                  Title           Sales
# 0            Minecraft  238,000,000[b]
# 1   Grand Theft Auto V     170,000,000
# 2          Tetris (EA)     100,000,000
# 3           Wii Sports      82,900,000
# 4  PUBG: Battlegrounds      75,000,000

# %%
df.loc[[0,1], "Platform(s)":"Publisher(s)[a]"]
# Out:
#          Platform(s)  Initial release date Developer(s)[a]    Publisher(s)[a]
# 0  Multi-platform[c]  November 18, 2011[d]  Mojang Studios  Xbox Game Studios
# 1     Multi-platform    September 17, 2013  Rockstar North     Rockstar Games

# %% [markdown]
# To set a new index, we can use df.set_index('the_colum', inplace = True) Inplace is to set the new index in the main df, to undo the new index there is a method to do that df.reset_index(inplace = True)
# we can also set the main column when we load the file with the method 'index_col = 'column name''

# %%
df.set_index('Title', inplace=True)

# %% [markdown]
# We can asign to a new variable a filter with a comparisson and concatenate mora than one filer with &(and), |(or), ~(negation of a filter)

# %%
nintendo = (df["Developer(s)[a]"] == "Nintendo EAD") | (df["Developer(s)[a]"] == "Nintendo R&D4")

# %%
df.loc[nintendo, 'Sales']
# Out:
# Title
# Wii Sports                   82,900,000
# Super Mario Bros.            58,000,000
# Mario Kart 8 / Deluxe        56,870,000
# Wii Fit / Plus               43,800,000
# Mario Kart Wii               37,380,000
# Wii Sports Resort            33,140,000
# New Super Mario Bros.        30,800,000
# New Super Mario Bros. Wii    30,320,000
# Wii Play                     28,020,000
# Super Mario World            26,662,500
# Super Mario Bros. 3          24,430,000
# Nintendogs                   23,960,000
# Mario Kart DS                23,600,000
# Name: Sales, dtype: object

# %% [markdown]
# We can pass a list trough a filt wit the method .isin
# We can use the string method .str.contains also to find a particular word in a string of many words

# %%
companies = ["Nintendo", "Sega", "Activision"]
filt_companies = df["Publisher(s)[a]"].isin(companies)
df.loc[filt_companies]
# Out:
#                                          Rank       Sales  \
# Title
# Wii Sports                                4.0  82,900,000
# Super Mario Bros.                         6.0  58,000,000
# Mario Kart 8 / Deluxe                     7.0  56,870,000
# Pokémon Red / Green / Blue / Yellow       8.0  47,520,000
# Wii Fit / Plus                           11.0  43,800,000
# Tetris (1989)[j]                         12.0  43,000,000
# Animal Crossing: New Horizons            14.0  40,170,000
# Mario Kart Wii                           16.0  37,380,000
# Wii Sports Resort                        17.0  33,140,000
# New Super Mario Bros.                    18.0  30,800,000
# New Super Mario Bros. Wii                19.0  30,320,000
# Call of Duty: Modern Warfare             20.0  30,000,000
# Super Smash Bros. Ultimate               24.0  29,530,000
# The Legend of Zelda: Breath of the Wild  25.0  29,490,000
# Pokémon Gold / Silver / Crystal          26.0         NaN
# ...

# %%
new_filt = df["Initial release date"].str.contains("September", na=False)
df.loc[new_filt]
# Out:
#                                     Rank        Sales            Series  \
# Title
# Grand Theft Auto V                   2.0  170,000,000  Grand Theft Auto
# Tetris (EA)                          3.0  100,000,000            Tetris
# Super Mario Bros.                    6.0   58,000,000       Super Mario
# Borderlands 2                       34.0   27,000,000       Borderlands
# Pokémon Diamond / Pearl / Platinum  38.0   24,730,000           Pokémon
# FIFA 18                             42.0   24,000,000              FIFA
#
#                                           Platform(s) Initial release date  \
# Title
# Grand Theft Auto V                     Multi-platform   September 17, 2013
# Tetris (EA)                         Multi-platform[e]   September 12, 2006
# Super Mario Bros.                   Multi-platform[f]   September 13, 1985
# Borderlands 2                          Multi-platform   September 18, 2012
# ...

# %% [markdown]
# We can change the columns for for upper or lower
# Replace letters or spaces with .str.replace
# Rename columns with the method .rename (we need to set inplace=True to modify the main df)
# We can change values for a certain row with list or if it is just one atribute we need to change no need for list

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#                                                   RANK           SALES  \
# Title
# Minecraft                                          1.0  238,000,000[b]
# Grand Theft Auto V                                 2.0     170,000,000
# Tetris (EA)                                        3.0     100,000,000
# Wii Sports                                         4.0      82,900,000
# PUBG: Battlegrounds                                5.0      75,000,000
# Super Mario Bros.                                  6.0      58,000,000
# Mario Kart 8 / Deluxe                              7.0      56,870,000
# Pokémon Red / Green / Blue / Yellow                8.0      47,520,000
# Red Dead Redemption 2                              9.0      46,000,000
# Terraria                                          10.0      44,500,000
# Wii Fit / Plus                                    11.0      43,800,000
# Tetris (1989)[j]                                  12.0      43,000,000
# ...

# %%
df.columns = df.columns.str.replace(" ", "_")
df

# %%
df.rename(columns = {"TITLE": "Game", "INITIAL_RELEASE_DATE": "Release Date"}, inplace=True)
df

# %%
df.loc[2, ["Game", "DEVELOPER(S)[A]"]] = ["Tetris", "EA"]
df

# %%
df["SERIES"] = df["SERIES"].str.lower()
df

# %% [markdown]
# .apply = In the pandas library, the apply() function is used to apply a function to each element of a Series (a column in a DataFrame) or to each row/column in a DataFrame. The function can be a built-in Python function or a user-defined function.
#
# We can use lambda functions or normal functions to pass inside the .apply method

# %% [markdown]
# EVERY TIME WE ACCES A COLUMN LIKE THIS df["COLUMN_NAME"] RETURS A SERIES
# IF WE ACCESS TO A FRAME LIKE THIS df.apply(function) WE ARE ACCESING TO JUST THE PROPERTYS OF THE COLUMNS, NOT TO ALL COLUMNS
# TO APPLY SOME FUNCTION TO ALL THE COLUMNS AND ROWS WE CAN DO IT BY TYPING THE METHOD df.applymap(function)

# %%
import math

def to_lower(series):
    return series.lower()

df["PLATFORM(S)"] = df["PLATFORM(S)"].apply(to_lower)

df["RANK"] = df["RANK"].apply(lambda x: math.floor(x))
# Out:
#                                                   RANK           SALES  \
# Title
# Minecraft                                            1  238,000,000[b]
# Grand Theft Auto V                                   2     170,000,000
# Tetris (EA)                                          3     100,000,000
# Wii Sports                                           4      82,900,000
# PUBG: Battlegrounds                                  5      75,000,000
# Super Mario Bros.                                    6      58,000,000
# Mario Kart 8 / Deluxe                                7      56,870,000
# Pokémon Red / Green / Blue / Yellow                  8      47,520,000
# Red Dead Redemption 2                                9      46,000,000
# Terraria                                            10      44,500,000
# Wii Fit / Plus                                      11      43,800,000
# Tetris (1989)[j]                                    12      43,000,000
# ...

# %% [markdown]
# To add a new column we can type df.["New Column Name"] = df.[x value] + funtions, other columns, etc
# To remove one or multiple we can use the method df.drop(columns=[column_1,Column_2]) and use inplace to settle the changes
