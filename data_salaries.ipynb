# %%
import pandas as pd

df = pd.read_csv("ds.salaries.csv")

df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [607 rows x 12 columns]

# %%
df_mi = df.loc[(df["experience_level"] == "MI")]
df_se = df.loc[(df["experience_level"] == "SE")]
df_en = df.loc[(df["experience_level"] == "EN")]
df_ex = df.loc[(df["experience_level"] == "EX")]

# %%
print(round(df_mi["salary_in_usd"].mean(), 2), round(df_mi["salary_in_usd"].std(),2))
print(round(df_se["salary_in_usd"].mean(), 2), round(df_se["salary_in_usd"].std(),2))
print(round(df_en["salary_in_usd"].mean(), 2), round(df_en["salary_in_usd"].std(),2))
print(round(df_ex["salary_in_usd"].mean(), 2), round(df_ex["salary_in_usd"].std(),2))
# Out:
# 87996.06 63901.06
# 138617.29 57691.98
# 61643.32 44395.54
# 199392.04 117071.26

# %%
def samples():L"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13268\2254631257.py in <module>
#       2 senior_salary = df_se["salary_in_usd"]
#       3
# ----> 4 new_df = pd.DataFrame[{"Senior": df_ex["salary_in_usd"]}]
#
# TypeError: 'type' object is not subscriptable

# %%
expert_salary
# Out:
# 25     325000
# 41      79833
# 73     150000
# 74     235000
# 84     153667
# 160    230000
# 161     85000
# 164    130026
# 167    250000
# 187     69741
# 225    416000
# 252    600000
# 259    141846
# 309    242000
# 310    200000
# 326    130000
# 327    110000
# 342    224000
# 343    167875
# 344    175000
# 368    135000
# 375    118187
# 384     79039
# 452    196979
# 482    324000
# 483    216000
# Name: salary_in_usd, dtype: int64
