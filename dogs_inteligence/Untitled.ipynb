# %%
import pandas as pd

int_df = pd.read_csv("dog_intelligence.csv")
size_df = pd.read_csv("AKC Breed Info.csv")


int_df.set_index('Breed', inplace = True)

int_df
# Out:
#                    index                                    Classification  \
# Breed
# Border Collie          0                                    Brightest Dogs
# Poodle                 1                                    Brightest Dogs
# German Shepherd        2                                    Brightest Dogs
# Golden Retriever       3                                    Brightest Dogs
# Doberman Pinscher      4                                    Brightest Dogs
# ...                  ...                                               ...
# Borzoi               131  Lowest Degree of Working/Obedience Intelligence
# Chow Chow            132  Lowest Degree of Working/Obedience Intelligence
# Bulldog              133  Lowest Degree of Working/Obedience Intelligence
# Basenji              134  Lowest Degree of Working/Obedience Intelligence
# Afghan Hound         135  Lowest Degree of Working/Obedience Intelligence
#
#                   obey  reps_lower  reps_upper
# Breed
# ...

# %%
size_df.set_index('Breed', inplace = True)

size_df
# Out:
#                       index height_low_inches height_high_inches  \
# Breed
# Akita                     0                26                 28
# Anatolian Sheepdog        1                27                 29
# Bernese Mountain Dog      2                23                 27
# Bloodhound                3                24                 26
# Borzoi                    4                26                 28
# ...                     ...               ...                ...
# Papillon                145                 8                 11
# Pomeranian              146                12                 12
# Poodle Toy              147                10                 10
# Toy Fox Terrier         148                10                 10
# Yorkshire Terrier       149                 8                  8
#
#                      weight_low_lbs weight_high_lbs
# Breed
# Akita                            80             120
# Anatolian Sheepdog              100             150
# ...

# %%
int_df.sort_index(inplace=True)
int_df
# Out:
#                              index  \
# Breed
# Affenpinscher                   53
# Afghan Hound                   135
# Airedale Terrier                36
# Akita                          102
# Alaskan Malamute                93
# ...                            ...
# West Highland White Terrier     85
# Whippet                         94
# Wire Fox Terrier                96
# Wirehaired Pointing Griffon     84
# Yorkshire Terrier               33
#
#                                                                Classification  \
# Breed
# Affenpinscher                                      Above Average Working Dogs
# Afghan Hound                 Lowest Degree of Working/Obedience Intelligence
# Airedale Terrier                                   Above Average Working Dogs
# Akita                                  Average Working/Obedience Intelligence
# Alaskan Malamute                       Average Working/Obedience Intelligence
# ...

# %%
size_df.sort_index(inplace=True)
size_df
# Out:
#                              index height_low_inches height_high_inches  \
# Breed
# Affenpinscher                  138                 9                 12
# Afghan Hound                    17                25                 27
# Airdale Terrier                 53                22                 24
# Akita                            0                26                 28
# Alaskan Malamute                18                na                 na
# ...                            ...               ...                ...
# Welsh Terrier                  135                15                 15
# West Highland White Terrier    136                11                 11
# Whippet                        137                18                 22
# Wirehaired Pointing Griffon     98                20                 24
# Yorkshire Terrier              149                 8                  8
#
#                             weight_low_lbs weight_high_lbs
# Breed
# ...

# %%
df = int_df.merge(size_df, left_index=True, right_index=True, how='outer')
df
# Out:
#                              index_x  \
# Breed
# Affenpinscher                   53.0
# Afghan Hound                   135.0
# Airdale Terrier                  NaN
# Airedale Terrier                36.0
# Akita                          102.0
# ...                              ...
# West Highland White Terrier     85.0
# Whippet                         94.0
# Wire Fox Terrier                96.0
# Wirehaired Pointing Griffon     84.0
# Yorkshire Terrier               33.0
#
#                                                                Classification  \
# Breed
# Affenpinscher                                      Above Average Working Dogs
# Afghan Hound                 Lowest Degree of Working/Obedience Intelligence
# Airdale Terrier                                                           NaN
# Airedale Terrier                                   Above Average Working Dogs
# Akita                                  Average Working/Obedience Intelligence
# ...
